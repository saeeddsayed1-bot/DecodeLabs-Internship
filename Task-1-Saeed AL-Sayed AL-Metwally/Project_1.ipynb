# %% [markdown]
# # Titanic Data Science Project

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv(r"D:\AI & ML\AI_ML Coding\Titanic-Dataset.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Dataset Understanding

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# ## Data Cleaning

# %%
df["Age"] = df["Age"].fillna(df["Age"].mean())
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df = df.drop("Cabin" , axis = 1)

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
sns.countplot(df , x = "Sex")
plt.title("Sex Distribution")
# Out:
# Text(0.5, 1.0, 'Sex Distribution')

# %%
sns.countplot(df , x = "Sex" , hue = "Survived")
plt.title("Suevived Distribution With Sex ")
# Out:
# Text(0.5, 1.0, 'Suevived Distribution With Sex ')

# %%
plt.hist(df["Age"] , bins = 10)
plt.title("Age Distribution")
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
df["Sex"].value_counts()
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   889.000000  889.000000  889.000000  889.000000  889.000000
# mean    446.000000    0.382452    2.311586   29.653446    0.524184
# std     256.998173    0.486260    0.834700   12.968366    1.103705
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     224.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.000000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  889.000000  889.000000
# mean     0.382452   32.096681
# std      0.806761   49.697504
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(df , x = "Pclass" , hue = "Survived")
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.boxplot(df , x= "Age")
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# ## Data Visualization

# %%
cat_cols = df.select_dtypes(include="object")
num_cols = df.select_dtypes(include="number")

# %%
sns.heatmap( num_cols.corr() )
# Out:
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder , OneHotEncoder

le = LabelEncoder()
df["Sex"] = le.fit_transform(df["Sex"])

df = pd.get_dummies(df , columns = ["Embarked"] , drop_first = True )

# %% [markdown]
# ## Machine Learning Model

# %%
x = df.drop(["Survived" , "Name" , "Ticket"] , axis = 1)
y = df["Survived"]
x
# Out:
#      PassengerId  Pclass  Sex        Age  SibSp  Parch     Fare  Embarked_Q  \
# 0              1       3    1  22.000000      1      0   7.2500       False
# 1              2       1    0  38.000000      1      0  71.2833       False
# 2              3       3    0  26.000000      0      0   7.9250       False
# 3              4       1    0  35.000000      1      0  53.1000       False
# 4              5       3    1  35.000000      0      0   8.0500       False
# ..           ...     ...  ...        ...    ...    ...      ...         ...
# 886          887       2    1  27.000000      0      0  13.0000       False
# 887          888       1    0  19.000000      0      0  30.0000       False
# 888          889       3    0  29.699118      1      2  23.4500       False
# 889          890       1    1  26.000000      0      0  30.0000       False
# 890          891       3    1  32.000000      0      0   7.7500        True
#
#      Embarked_S
# 0          True
# 1         False
# ...

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split( x , y , test_size = 0.2 ,random_state = 42 )

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(  )
model.fit(x_train , y_train)
# Out:
# c:\Users\Saee\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model.score(x_train , y_train)
# Out:
# 0.7876230661040787

# %%
model.score(x_test , y_test )
# Out:
# 0.797752808988764

# %% [markdown]
# ## Prediction

# %%
model.predict([[1, 1, 0, 25, 0, 0, 80, False, True]])
# Out:
# c:\Users\Saee\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %% [markdown]
# ## Conclusion
#
# In this project, the Titanic dataset was analyzed and cleaned using Python libraries such as Pandas, Matplotlib, and Seaborn.
#
# Different visualizations were created to understand patterns in the data. The analysis showed that female passengers and first-class passengers had a higher survival rate.
#
# A Logistic Regression model was built to predict passenger survival, achieving an accuracy of approximately 80%.
#
# This project helped in understanding the complete Data Science workflow, including data cleaning, exploratory data analysis, visualization, preprocessing, and machine learning.
